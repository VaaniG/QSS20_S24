# %%
import pandas as pd
# Out:
# /Users/vaanigupta/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
df = pd.read_pickle("covid_sample-0.0001.pkl")

# %%
df
# Out:
#                     tweetid               userid      screen_name  \
# 29075   1440152419048955908  1389342585823584263  josephc14074803
# 17272   1347878795554918403            440160509      Iela_Strika
# 38446   1271326636760162304  1022641129655742467          YngShvy
# 16418   1279673408905756672            260230964     jennycoady10
# 53175   1342267014686109701            281225798     certezamente
# ...                     ...                  ...              ...
# 47554   1453744714730012677             19994423         dfarquha
# 10511   1221572642257481729  1109532876310302721      donkamion78
# 161110  1477836631067566081  1285057167884722178       bIuesundae
# 11663   1496954995488419850           3320990612  JThomasOfficial
# 9549    1338380381398175746  1333862034933428230    idrisdemirsoy
#
#                                   date lang                   location  \
# 29075   Tue Sep 21 03:14:28 +0000 2021   en                        NaN
# ...

# %%
df.columns
# Out:
# Index(['tweetid', 'userid', 'screen_name', 'date', 'lang', 'location',
#        'place_id', 'place_url', 'place_type', 'place_name', 'place_full_name',
#        'place_country_code', 'place_country', 'place_bounding_box', 'text',
#        'extended', 'coord', 'reply_userid', 'reply_screen', 'reply_statusid',
#        'tweet_type', 'friends_count', 'listed_count', 'followers_count',
#        'favourites_count', 'statuses_count', 'verified', 'hashtag',
#        'urls_list', 'profile_pic_url', 'profile_banner_url', 'display_name',
#        'date_first_tweet', 'account_creation_date', 'rt_urls_list',
#        'mentionid', 'mentionsn', 'rt_screen', 'rt_userid', 'rt_text',
#        'rt_hashtag', 'rt_qtd_count', 'rt_rt_count', 'rt_reply_count',
#        'rt_fav_count', 'rt_tweetid', 'rt_location', 'qtd_screen', 'qtd_userid',
#        'qtd_text', 'qtd_hashtag', 'qtd_qtd_count', 'qtd_rt_count',
#        'qtd_reply_count', 'qtd_fav_count', 'qtd_tweetid', 'qtd_urls_list',
# ...

# %%
df_main = pd.read_pickle("covid_sample-0.001.pkl")
df_main
# Out:
#                     tweetid               userid    screen_name  \
# 15605   1220641644367765504   747463650881970176   gareth_grier
# 16910   1220640235358281729   937270922234363905      Rose_ifnt
# 8796    1220632931489574913           3869545214     SinoVoices
# 14795   1220642433127436288           1053953342  _KhairiHassan
# 4225    1220640550178762753  1104714610421190656    Gaz60656269
# ...                     ...                  ...            ...
# 90900   1482664673854038016            508859323      laudemare
# 22201   1482656524245909507  1390529577760530433     Justbob111
# 81791   1482663571716775936  1464936163123281923     falcon2800
# 88826   1482664418727145473            798161712    KevinSalvat
# 102639  1482666092438953995  1327585064541106177   claveledith1
#
#                                   date lang       location place_id place_url  \
# 15605   Fri Jan 24 09:37:01 +0000 2020   en            NaN      NaN       NaN
# ...

# %%
df_main.columns
# Out:
# Index(['tweetid', 'userid', 'screen_name', 'date', 'lang', 'location',
#        'place_id', 'place_url', 'place_type', 'place_name', 'place_full_name',
#        'place_country_code', 'place_country', 'place_bounding_box', 'text',
#        'extended', 'coord', 'reply_userid', 'reply_screen', 'reply_statusid',
#        'tweet_type', 'friends_count', 'listed_count', 'followers_count',
#        'favourites_count', 'statuses_count', 'verified', 'hashtag',
#        'urls_list', 'profile_pic_url', 'profile_banner_url', 'display_name',
#        'date_first_tweet', 'account_creation_date', 'rt_urls_list',
#        'mentionid', 'mentionsn', 'rt_screen', 'rt_userid', 'rt_text',
#        'rt_hashtag', 'rt_qtd_count', 'rt_rt_count', 'rt_reply_count',
#        'rt_fav_count', 'rt_tweetid', 'rt_location', 'qtd_screen', 'qtd_userid',
#        'qtd_text', 'qtd_hashtag', 'qtd_qtd_count', 'qtd_rt_count',
#        'qtd_reply_count', 'qtd_fav_count', 'qtd_tweetid', 'qtd_urls_list',
# ...

# %%
df_subset = df_main[df_main["lang"] == "en"]
df_subset = df_main[df_main["place_country"] == "United States"]
df_subset[["userid", "text", "tweetid", "rt_tweetid", "tweet_type", "rt_userid"]]
# Out:
#                     userid                                               text  \
# 16174   811726983252086784  China Has Not Accepted U.S. Offers to Send CDC...
# 15175            262431835  I knew k-state was superior! and that’s on cor...
# 7331             125534675  We received a note Thursday from Luo Daiqing’s...
# 49382             23781293           @NPR This looks like the movie Outbreak!
# 41318             25096956  Actually, worry about both.  One doesn’t dimin...
# ...                    ...                                                ...
# 63521            164752952       Now would be a great time for #GeneralStrike
# 70154           2445700028                                    Covidiot logic!
# 5948            2373040398                                         🙏🏾🙏🏾🙏🏾🙏🏾🙏🏾
# 178453            35883927       What to look for if you think you have covid
# 116621           239448774  Hello.  Is this not news? @FoxNews @foxnation ...
#
# ...

# %%
df_subset[(df_subset["userid"] == 1104714610421190656) | (df_subset["rt_userid"] == 1104714610421190656)]
# Out:
#                   tweetid               userid  screen_name  \
# 4225  1220640550178762753  1104714610421190656  Gaz60656269
#
#                                 date lang location place_id place_url  \
# 4225  Fri Jan 24 09:32:40 +0000 2020   en      NaN      NaN       NaN
#
#      place_type place_name  ...      rt_country qtd_state qtd_country  \
# 4225        NaN        NaN  ...  United Kingdom       NaN         NaN
#
#      norm_country norm_rt_country norm_qtd_country description  \
# 4225          NaN  United Kingdom              NaN         NaN
#
#       rt_user_description qtd_user_description  acc_age
# 4225                  NaN                  NaN      NaN
#
# [1 rows x 76 columns]

# %%
df_subset
# Out:
#                     tweetid              userid      screen_name  \
# 16174   1222318437785047040  811726983252086784          Nars_br
# 15175   1222319059196436481           262431835        addiejoxo
# 7331    1220515450695581701           125534675    RyanFaircloth
# 49382   1221056407803518977            23781293   AlligatorPurse
# 41318   1222679565169909761            25096956  EvlJunglePrince
# ...                     ...                 ...              ...
# 63521   1481662601910231047           164752952      AllFowledUp
# 70154   1484653374813483012          2445700028         dagimbel
# 5948    1478501971288117259          2373040398     TheRealErik3
# 178453  1478516434292588550            35883927         dlg31464
# 116621  1483796121512206336           239448774        BatJordan
#
#                                   date lang                    location  \
# 16174   Wed Jan 29 00:39:59 +0000 2020   en                  Texas, USA
# ...
