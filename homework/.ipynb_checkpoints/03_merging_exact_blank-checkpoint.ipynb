# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import os

## repeated printouts
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# Out:
# /Users/vaanigupta/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %% [markdown]
# ## Read in data and make sure relevant columns are string/character
#
# - San Diego data: `naics_code` and `account_key`
# - NAICS details data: `naics`
#
# Run code below; if pulling from github, pathname should be fine; if working elsewhere may need to edit path name at read in

# %%
# uncomment if u need to find your path: os.getcwd()
SD = sd_df = pd.read_csv("../public_data/sd_df.csv")
NA = naics_df = pd.read_csv("../public_data/naics_df.csv")

# %%
cols_sd_use = ["naics_code", "account_key"]
cols_naics_use = ["naics"]

sd_df[cols_sd_use] = sd_df[cols_sd_use].astype(str)
naics_df[cols_naics_use] = naics_df[cols_naics_use].astype(str)

sd_df.dtypes
naics_df.dtypes
sd_df.head()
naics_df.head()
# Out:
# account_key          object
# dba_name             object
# council_district     object
# naics_code           object
# naics_description    object
# naics_nchar           int64
# dtype: object
# naics                object
# naics_description    object
# dtype: object
#   account_key                                      dba_name council_district  \
# 0  1974000448                             ERNST & YOUNG LLP             cd_1
# 1  1974011093  HECHT SOLBERG ROBINSON GOLDBERG & BAGLEY LLP             cd_3
# 2  1978039819                                    RSM US LLP             cd_1
# 3  1978042092               THORSNES BARTOLOTTA MCGUIRE LLP             cd_3
# 4  1979046817                       KORENIC & WOJDOWSKI LLP             cd_7
#
#   naics_code                              naics_description  naics_nchar
# 0     541211        OFFICES OF CERTIFIED PUBLIC ACCOUNTANTS            6
# 1       5411                                 LEGAL SERVICES            4
# 2     541211        OFFICES OF CERTIFIED PUBLIC ACCOUNTANTS            6
# 3       5411                                 LEGAL SERVICES            4
# 4       5412  ACCOUNTING/TAX PREP/BOOKKEEP/PAYROLL SERVICES            4
#     naics                 naics_description
# 0  111140                     Wheat Farming
# 1  111160                      Rice Farming
# 2  111150                      Corn Farming
# 3  111110                   Soybean Farming
# 4  111120  Oilseed (except Soybean) Farming

# %% [markdown]
# ## "Inner join"- retain only San Diego businesses with details on their NAICS code
#
# - Use the `naics_code` column in the San Diego business data as the join key
# - Use the `naics` column in the NAICS code details data as the join key
#
# - Do an inner join of the San Diego data onto the NAICS code details using these join keys
# - After the inner join, print some examples of San Diego businesses lost in the merge
# - Use value_counts() on the `naics_nchar` column in the San Diego data to see why they might have gotten lost

# %%
# your code here
df_join = naics_df.merge(sd_df, right_on = "naics_code", left_on="naics", how="inner")
df_join.head()
sd_df["naics_nchar"].value_counts()
df_join["naics_nchar"].value_counts()
# Out:
#     naics                         naics_description_x account_key  \
# 0  311999  All Other Miscellaneous Food Manufacturing  2020007786
# 1  311999  All Other Miscellaneous Food Manufacturing  2020007786
# 2  311999  All Other Miscellaneous Food Manufacturing  2020007786
# 3  311999  All Other Miscellaneous Food Manufacturing  2020007786
# 4  311999  All Other Miscellaneous Food Manufacturing  2020007786
#
#                 dba_name council_district naics_code  \
# 0  PRIMAL COFFEE COMPANY             cd_2     311999
# 1  PRIMAL COFFEE COMPANY             cd_2     311999
# 2  PRIMAL COFFEE COMPANY             cd_2     311999
# 3  PRIMAL COFFEE COMPANY             cd_2     311999
# 4  PRIMAL COFFEE COMPANY             cd_2     311999
#
#                 naics_description_y  naics_nchar
# 0  ALL OTHER MISCELLANEOUS FOOD MFG            6
# 1  ALL OTHER MISCELLANEOUS FOOD MFG            6
# 2  ALL OTHER MISCELLANEOUS FOOD MFG            6
# 3  ALL OTHER MISCELLANEOUS FOOD MFG            6
# 4  ALL OTHER MISCELLANEOUS FOOD MFG            6
# naics_nchar
# 5    150
# 4     89
# 6     49
# 3     42
# 2     23
# Name: count, dtype: int64
# naics_nchar
# 6    52
# Name: count, dtype: int64

# %% [markdown]
# ## "Left join"- retain all sd businesses even if naics code isn't in `naics_df`
#
# - Using the same join keys as above, and treating the San Diego businesses as the left hand side data, left join the naics code details onto the San Diego businesses
# - Use the `indicator` argument within merge to create an indicator, `naics_merge_status`, to help with later merge diagnostics and examine sample of ones that didn't merge
# - Use the `suffixes` argument within merge to add `_sd` as the left suffix, `_census` as the right suffix
# - Use `naics_merge_status` in the merged result to look at a sample of San Diego businesses that weren't matched with `naics_df`

# %%
# your code here
df_left_join = sd_df.merge(naics_df, left_on = "naics_code", right_on="naics", how="left", suffixes=("_sd", "_census"), indicator="naics_merge_status")
df_left_join.head()
df_left_join[df_left_join["naics_merge_status"] != "both"].head()
# Out:
#   account_key                                      dba_name council_district  \
# 0  1974000448                             ERNST & YOUNG LLP             cd_1
# 1  1974011093  HECHT SOLBERG ROBINSON GOLDBERG & BAGLEY LLP             cd_3
# 2  1978039819                                    RSM US LLP             cd_1
# 3  1978042092               THORSNES BARTOLOTTA MCGUIRE LLP             cd_3
# 4  1979046817                       KORENIC & WOJDOWSKI LLP             cd_7
#
#   naics_code                           naics_description_sd  naics_nchar  \
# 0     541211        OFFICES OF CERTIFIED PUBLIC ACCOUNTANTS            6
# 1       5411                                 LEGAL SERVICES            4
# 2     541211        OFFICES OF CERTIFIED PUBLIC ACCOUNTANTS            6
# 3       5411                                 LEGAL SERVICES            4
# 4       5412  ACCOUNTING/TAX PREP/BOOKKEEP/PAYROLL SERVICES            4
#
#     naics                 naics_description_census naics_merge_status
# 0  541211  Offices of Certified Public Accountants               both
# 1     NaN                                      NaN          left_only
# 2  541211  Offices of Certified Public Accountants               both
# 3     NaN                                      NaN          left_only
# 4     NaN                                      NaN          left_only
#   account_key                                      dba_name council_district  \
# 1  1974011093  HECHT SOLBERG ROBINSON GOLDBERG & BAGLEY LLP             cd_3
# 3  1978042092               THORSNES BARTOLOTTA MCGUIRE LLP             cd_3
# 4  1979046817                       KORENIC & WOJDOWSKI LLP             cd_7
# 5  1979053082    GRIMM VRANJES GREER STEPHAN & BRIDGMAN LLP             cd_3
# 6  1981000840                          BENINK & SLAVENS LLP             cd_7
#
#   naics_code                           naics_description_sd  naics_nchar  \
# 1       5411                                 LEGAL SERVICES            4
# 3       5411                                 LEGAL SERVICES            4
# 4       5412  ACCOUNTING/TAX PREP/BOOKKEEP/PAYROLL SERVICES            4
# 5       5411                                 LEGAL SERVICES            4
# 6       5411                                 LEGAL SERVICES            4
#
#   naics naics_description_census naics_merge_status
# 1   NaN                      NaN          left_only
# 3   NaN                      NaN          left_only
# 4   NaN                      NaN          left_only
# 5   NaN                      NaN          left_only
# 6   NaN                      NaN          left_only

# %% [markdown]
# ## Use group by and agg to see if there are differences in merge rates by area
#
# - Using the left-joined dataframe created in previous step, create a boolean indicator, `is_lost`, that equals `True` if the merge indicator is equal to "left_only" (and is otherwise false)
# - Find the proportion of businesses by council district that were lost in the left join (SD businesses that failed to match to `naics_df`). To do this, group by `council_district` and use the shortcut of taking the mean of the `is_lost` indicator to find the proportions lost by `council_district`.

# %%
# your code here
is_lost = df_left_join["naics_merge_status"] == "left_only"
df_left_join["is_lost"] = is_lost
res = df_left_join.groupby("council_district")["is_lost"].mean()
res
# Out:
# council_district
# cd_1    0.880597
# cd_2    0.804348
# cd_3    0.812500
# cd_4    1.000000
# cd_5    0.916667
# cd_6    0.859649
# cd_7    0.918919
# cd_8    0.933333
# cd_9    1.000000
# Name: is_lost, dtype: float64

# %% [markdown]
# ## Optional challenge exercise: add lagging 0's and see if merge rate improves
#
# You noticed earlier that a big reason for non-matches is that the San Diego tax certificate NAICS codes were often less than six digits long, while the Census ones were always 6 digits.
#
# You wonder if this is an issue where 0's in some of the SD's data naics codes got cut off (eg 540000 became 54), and if so whether adding these lagging zeros would improve the merge rate in a left join.
#
# - Pad the `naics_code` column in `sd_df` with 0's to get that column up to 6-digits, using one of two approaches:
#   1. `str.pad` in pandas (https://pandas.pydata.org/docs/reference/api/pandas.Series.str.pad.html)
#   2. for more of a challenge, write your own function! It should check the # of digits in the naics code string and pad it with 0's at the end up to 6 digits. To execute your function, use row-wise apply: `df.apply(lambda row: funcname(row.column), axis=1)`.
# - Perform the same left join as above and see how the match rate changes
# - Create an indicator variable--`is_new_match`---for new matches under the padded NAICS code; compare the `naics_description` column from San Diego versus Census in the new dataset for a sample of these new matches and comment on whether the padding seems to be correct

# %%
# your code here
sd_df["naics_code_pad"] = sd_df["naics_code"].str.pad(width=6, side='right', fillchar='0')

df_left_pad = sd_df.merge(naics_df, left_on = "naics_code_pad", right_on="naics", how="left", suffixes=("_sd", "_census"), indicator="naics_merge_status")
df_left_pad.head()
is_new_match = df_left_pad["naics_description_sd"].str.lower() == df_left_pad["naics_description_census"].str.lower()
df_left_pad[is_new_match].sample(n=20)
df_left_pad.naics_merge_status.value_counts()
df_left_join.naics_merge_status.value_counts()
# padding seems to be correct!
# Out:
#   account_key                                      dba_name council_district  \
# 0  1974000448                             ERNST & YOUNG LLP             cd_1
# 1  1974011093  HECHT SOLBERG ROBINSON GOLDBERG & BAGLEY LLP             cd_3
# 2  1978039819                                    RSM US LLP             cd_1
# 3  1978042092               THORSNES BARTOLOTTA MCGUIRE LLP             cd_3
# 4  1979046817                       KORENIC & WOJDOWSKI LLP             cd_7
#
#   naics_code                           naics_description_sd  naics_nchar  \
# 0     541211        OFFICES OF CERTIFIED PUBLIC ACCOUNTANTS            6
# 1       5411                                 LEGAL SERVICES            4
# 2     541211        OFFICES OF CERTIFIED PUBLIC ACCOUNTANTS            6
# 3       5411                                 LEGAL SERVICES            4
# 4       5412  ACCOUNTING/TAX PREP/BOOKKEEP/PAYROLL SERVICES            4
#
#   naics_code_pad   naics                 naics_description_census  \
# 0         541211  541211  Offices of Certified Public Accountants
# 1         541100     NaN                                      NaN
# 2         541211  541211  Offices of Certified Public Accountants
# 3         541100     NaN                                      NaN
# 4         541200     NaN                                      NaN
#
#   naics_merge_status
# 0               both
# 1          left_only
# 2               both
# 3          left_only
# 4          left_only
#     account_key                              dba_name council_district  \
# 357  2020005844               MICROVISION OPTICAL LLC             cd_1
# 341  2019025122                           VALMARE LLC             cd_3
# 340  2019025122                           VALMARE LLC             cd_3
# 290  2018027955                   DR BOYDS PET RESORT             cd_3
# 368  2020006728                  FOODS ON THE FLY LLC             cd_6
# 164  2008026162              SABRE SPRINGS ARCO AM PM             cd_5
# 213  2014027828              STEES WALKER COMPANY LLP             cd_5
# 85   2005004342                STARK & D'AMBROSIO LLP             cd_3
# 273  2018006953                EDWARD D JONES & CO LP             cd_5
# 375  2020007523                       ODAI AUTO SALES             cd_6
# 170  2009003243          ALTMAN INVESTMENT COMPANY LP             cd_1
# 389  2020009654                          EDWARD JONES             cd_5
# 234  2015048818               ALPHA SQUARE APARTMENTS             cd_7
# 108  2006010738                 WENTHUR LAW GROUP LLP             cd_2
# 367  2020006672                      TEXLA TECHNOLOGY             cd_7
# 289  2018027955                   DR BOYDS PET RESORT             cd_3
# 288  2018027955                   DR BOYDS PET RESORT             cd_3
# 194  2012000181                 PEOPLES LAW GROUP LLP             cd_3
# 78   2004008692                         TM GLOBAL LLP             cd_1
# 264  2018000234  VINAS UNITED CRYPTO INVESTMENT GROUP             cd_6
#
#     naics_code                           naics_description_sd  naics_nchar  \
# 357      44613                           OPTICAL GOODS STORES            5
# 341      45439            OTHER DIRECT SELLING ESTABLISHMENTS            5
# 340      45439            OTHER DIRECT SELLING ESTABLISHMENTS            5
# 290      54194                            VETERINARY SERVICES            5
# 368      72231                       FOOD SERVICE CONTRACTORS            5
# 164      44711      GASOLINE STATIONS WITH CONVENIENCE STORES            5
# 213     541211        OFFICES OF CERTIFIED PUBLIC ACCOUNTANTS            6
# 85       54111                             OFFICES OF LAWYERS            5
# 273      52312                           SECURITIES BROKERAGE            5
# 375      44112                               USED CAR DEALERS            5
# 170     531312               NONRESIDENTIAL PROPERTY MANAGERS            6
# 389      52312                           SECURITIES BROKERAGE            5
# 234      53139        OTHER ACTIVITIES RELATED TO REAL ESTATE            5
# 108     541199                       ALL OTHER LEGAL SERVICES            6
# 367      54133                           ENGINEERING SERVICES            5
# 289      54194                            VETERINARY SERVICES            5
# 288      54194                            VETERINARY SERVICES            5
# 194      54111                             OFFICES OF LAWYERS            5
# 78       53139        OTHER ACTIVITIES RELATED TO REAL ESTATE            5
# 264     523999  MISCELLANEOUS FINANCIAL INVESTMENT ACTIVITIES            6
#
#     naics_code_pad   naics                       naics_description_census  \
# 357         446130  446130                           Optical Goods Stores
# 341         454390  454390            Other Direct Selling Establishments
# 340         454390  454390            Other Direct Selling Establishments
# 290         541940  541940                            Veterinary Services
# 368         722310  722310                       Food Service Contractors
# 164         447110  447110      Gasoline Stations with Convenience Stores
# 213         541211  541211        Offices of Certified Public Accountants
# 85          541110  541110                             Offices of Lawyers
# 273         523120  523120                           Securities Brokerage
# 375         441120  441120                               Used Car Dealers
# 170         531312  531312               Nonresidential Property Managers
# 389         523120  523120                           Securities Brokerage
# 234         531390  531390        Other Activities Related to Real Estate
# 108         541199  541199                       All Other Legal Services
# 367         541330  541330                           Engineering Services
# 289         541940  541940                            Veterinary Services
# 288         541940  541940                            Veterinary Services
# 194         541110  541110                             Offices of Lawyers
# 78          531390  531390        Other Activities Related to Real Estate
# 264         523999  523999  Miscellaneous Financial Investment Activities
#
#     naics_merge_status
# 357               both
# 341               both
# 340               both
# 290               both
# 368               both
# 164               both
# 213               both
# 85                both
# 273               both
# 375               both
# 170               both
# 389               both
# 234               both
# 108               both
# 367               both
# 289               both
# 288               both
# 194               both
# 78                both
# 264               both
# naics_merge_status
# both          237
# left_only     209
# right_only      0
# Name: count, dtype: int64
# naics_merge_status
# left_only     318
# both           52
# right_only      0
# Name: count, dtype: int64
